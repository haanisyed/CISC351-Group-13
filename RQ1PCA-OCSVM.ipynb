# %% [markdown]
# ## Import Necessary Libraries for Study

# %%
import os
import re
import cv2
import numpy as np
from skimage.feature import hog
from sklearn.svm import OneClassSVM
from sklearn.decomposition import PCA

# %% [markdown]
# ## Configuration and Application of Images for PCA + SVM

# %%
# Define paths
IMG_DIR = "/Users/annethsivakumar/Downloads/Left_images2/"
OUTPUT_DIR = "/Users/annethsivakumar/Downloads/classified_output/"

# Ensure output directory exists
os.makedirs(OUTPUT_DIR, exist_ok=True)

# Get all .png images in the directory (sorted numerically)
image_files = sorted(
    [f for f in os.listdir(IMG_DIR) if f.endswith(".png")],
    key=lambda x: int(re.findall(r'\d+', x)[0]) if re.findall(r'\d+', x) else 0
)

# PCA and SVM parameters
# Sliding-window patch size and step.
PATCH_SIZE = (32, 32)    # (width, height)
STEP_SIZE = (16, 16)    # (step_x, step_y)
# One-Class SVM parameters.
OCSVM_NU = 0.1        # Proportion of outliers you expect
OCSVM_KERNEL = 'rbf'
OCSVM_GAMMA = 'auto'

# PCA parameters.
N_COMPONENTS = 50    # Number of principal components to keep (adjust as needed)

# Color histogram parameters.
COLOR_BINS = (8, 8, 8)    # number of bins for each channel

# HOG parameters.
HOG_PARAMS = {
    'pixels_per_cell': (8, 8),
    'cells_per_block': (2, 2),
    'orientations': 9,
    'block_norm': 'L2-Hys'
}

# Filtering thresholds.
# 1) Minimum number of patches in a connected component (in patch-space).
MIN_COMPONENT_AREA_PATCHES = 10
# 2) Minimum bounding box area in pixel-space.
MIN_BBOX_AREA_PX = 2000

# Functions for extracting features
def color_histogram_features(patch_bgr, bins=(8, 8, 8)):
    """
    Compute a 3D color histogram (B, G, R) and normalize it.
    """
    hist_b = cv2.calcHist([patch_bgr], [0], None, [bins[0]], [0, 256]).flatten()
    hist_g = cv2.calcHist([patch_bgr], [1], None, [bins[1]], [0, 256]).flatten()
    hist_r = cv2.calcHist([patch_bgr], [2], None, [bins[2]], [0, 256]).flatten()
    hist_b /= (hist_b.sum() + 1e-6)
    hist_g /= (hist_g.sum() + 1e-6)
    hist_r /= (hist_r.sum() + 1e-6)
    return np.concatenate([hist_b, hist_g, hist_r])

def hog_features(patch_bgr):
    """
    Compute HOG on the grayscale version of the patch.
    """
    patch_gray = cv2.cvtColor(patch_bgr, cv2.COLOR_BGR2GRAY)
    return hog(patch_gray, **HOG_PARAMS)

def extract_patch_features(patch_bgr):
    """
    Combine color histogram + HOG into a single feature vector.
    """
    return np.concatenate([color_histogram_features(patch_bgr, COLOR_BINS), hog_features(patch_bgr)])

def sliding_window(image, step_size, window_size):
    """
    Generator yielding (x, y, patch) for each top-left corner (x, y).
    """
    max_y = image.shape[0] - window_size[1] + 1
    max_x = image.shape[1] - window_size[0] + 1
    for y in range(0, max_y, step_size[1]):
        for x in range(0, max_x, step_size[0]):
            yield (x, y, image[y:y+window_size[1], x:x+window_size[0]])

# Process each image in the directory
for img_file in image_files:
    IMG_PATH = os.path.join(IMG_DIR, img_file)
    OUTPUT_PATH = os.path.join(OUTPUT_DIR, img_file)
    
    print(f"Processing: {IMG_PATH}")

    # Load image
    img_bgr = cv2.imread(IMG_PATH)
    if img_bgr is None:
        print(f"Error loading {IMG_PATH}")
        continue

    # Extract patches and features
    features_list, coords_list = [], []
    for (x, y, patch_bgr) in sliding_window(img_bgr, STEP_SIZE, PATCH_SIZE):
        feat = extract_patch_features(patch_bgr)
        features_list.append(feat)
        coords_list.append((x, y))

    features_array = np.array(features_list, dtype=np.float32)
    if features_array.shape[0] == 0:
        print(f"No valid patches extracted from {IMG_PATH}")
        continue

    # Apply PCA
    n_features = features_array.shape[1]
    n_components = min(N_COMPONENTS, n_features)
    pca = PCA(n_components=n_components, random_state=42)
    features_array_pca = pca.fit_transform(features_array)

    # Train One-Class SVM and predict anomalies
    ocsvm = OneClassSVM(nu=OCSVM_NU, kernel=OCSVM_KERNEL, gamma=OCSVM_GAMMA)
    ocsvm.fit(features_array_pca)
    predictions = ocsvm.predict(features_array_pca)  # +1 = normal, -1 = outlier

    # Convert predictions to a 2D mask
    img_h, img_w = img_bgr.shape[:2]
    grid_rows = (img_h - PATCH_SIZE[1]) // STEP_SIZE[1] + 1
    grid_cols = (img_w - PATCH_SIZE[0]) // STEP_SIZE[0] + 1
    anomaly_mask = np.zeros((grid_rows, grid_cols), dtype=np.uint8)

    for i, pred in enumerate(predictions):
        if pred == -1:
            row = i // grid_cols
            col = i % grid_cols
            anomaly_mask[row, col] = 255

    # Apply morphological opening
    kernel = np.ones((3, 3), np.uint8)
    anomaly_mask = cv2.morphologyEx(anomaly_mask, cv2.MORPH_OPEN, kernel)

    # Connected components analysis
    num_labels, labels, stats, centroids = cv2.connectedComponentsWithStats(anomaly_mask, connectivity=8)
    annotated_img = img_bgr.copy()
    object_count = 0

    for label_id in range(1, num_labels):
        component_area = stats[label_id, cv2.CC_STAT_AREA]
        if component_area < MIN_COMPONENT_AREA_PATCHES:
            continue

        x_patch = stats[label_id, cv2.CC_STAT_LEFT]
        y_patch = stats[label_id, cv2.CC_STAT_TOP]
        w_patch = stats[label_id, cv2.CC_STAT_WIDTH]
        h_patch = stats[label_id, cv2.CC_STAT_HEIGHT]

        x_min_pixel = x_patch * STEP_SIZE[0]
        y_min_pixel = y_patch * STEP_SIZE[1]
        x_max_pixel = (x_patch + w_patch - 1) * STEP_SIZE[0] + PATCH_SIZE[0]
        y_max_pixel = (y_patch + h_patch - 1) * STEP_SIZE[1] + PATCH_SIZE[1]

        bbox_width = x_max_pixel - x_min_pixel
        bbox_height = y_max_pixel - y_min_pixel
        bbox_area = bbox_width * bbox_height

        if bbox_area < MIN_BBOX_AREA_PX:
            continue

        # Draw bounding box
        object_count += 1
        cv2.rectangle(annotated_img, (x_min_pixel, y_min_pixel), (x_max_pixel, y_max_pixel), (0, 0, 255), 2)

        # Label the bounding box
        label_text = f"Object #{object_count}"
        text_x = x_min_pixel
        text_y = max(y_min_pixel - 5, 15)
        cv2.putText(annotated_img, label_text, (text_x, text_y), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 0, 255), 2)

    # Save annotated image
    success = cv2.imwrite(OUTPUT_PATH, annotated_img)
    if success:
        print(f"Saved annotated image to: {OUTPUT_PATH}")
    else:
        print("Error: Could not write image. Check OUTPUT_PATH and extension.")

print("Processing complete.")
# Out:
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001640.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001640.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001641.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001641.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001642.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001642.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001643.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001643.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001644.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001644.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001645.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001645.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001646.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001646.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001647.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001647.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001648.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001648.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001649.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001649.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001650.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001650.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001651.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001651.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001652.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001652.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001653.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001653.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001654.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001654.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001655.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001655.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001656.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001656.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001657.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001657.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001658.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001658.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001659.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001659.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001660.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001660.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001661.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001661.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001662.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001662.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001663.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001663.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001664.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001664.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001665.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001665.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001666.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001666.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001667.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001667.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001668.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001668.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001669.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001669.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001670.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001670.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001671.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001671.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001672.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001672.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001673.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001673.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001674.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001674.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001675.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001675.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001676.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001676.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001677.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001677.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001678.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001678.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001679.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001679.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001680.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001680.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001681.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001681.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001682.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001682.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001683.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001683.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001684.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001684.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001685.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001685.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001686.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001686.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001687.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001687.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001688.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001688.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001689.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001689.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001690.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001690.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001691.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001691.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001692.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001692.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001693.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001693.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001694.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001694.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001695.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001695.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001696.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001696.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001697.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001697.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001698.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001698.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001699.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001699.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001700.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001700.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001701.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001701.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001702.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001702.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001703.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001703.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001704.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001704.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001705.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001705.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001706.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001706.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001707.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001707.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001708.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001708.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001709.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001709.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001710.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001710.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001711.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001711.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001712.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001712.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001713.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001713.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001714.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001714.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001715.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001715.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001716.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001716.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001717.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001717.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001718.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001718.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001719.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001719.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001720.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001720.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001721.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001721.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001722.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001722.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001723.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001723.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001724.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001724.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001725.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001725.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001726.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001726.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001727.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001727.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001728.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001728.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001729.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001729.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001730.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001730.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001731.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001731.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001732.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001732.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001733.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001733.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001734.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001734.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001735.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001735.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001736.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001736.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001737.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001737.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001738.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001738.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001739.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001739.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001740.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001740.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001741.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001741.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001742.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001742.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001743.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001743.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001744.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001744.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001745.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001745.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001746.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001746.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001747.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001747.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001748.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001748.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001749.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001749.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001750.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001750.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001751.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001751.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001752.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001752.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001753.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001753.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001754.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001754.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001755.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001755.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001756.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001756.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001757.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001757.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001758.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001758.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001759.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001759.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001760.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001760.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001761.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001761.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001762.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001762.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001763.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001763.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001764.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001764.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001765.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001765.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001766.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001766.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001767.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001767.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001768.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001768.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001769.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001769.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001770.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001770.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001771.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001771.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001772.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001772.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001773.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001773.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001774.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001774.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001775.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001775.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001776.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001776.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001777.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001777.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001778.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001778.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001779.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001779.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001780.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001780.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001781.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001781.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001782.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001782.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001783.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001783.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001784.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001784.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001785.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001785.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001786.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001786.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001787.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001787.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001788.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001788.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001789.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001789.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001790.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001790.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001791.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001791.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001792.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001792.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001793.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001793.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001794.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001794.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001795.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001795.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001796.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001796.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001797.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001797.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001798.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001798.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001799.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001799.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001800.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001800.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001801.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001801.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001802.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001802.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001803.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001803.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001804.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001804.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001805.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001805.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001806.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001806.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001807.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001807.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001808.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001808.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001809.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001809.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001810.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001810.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001811.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001811.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001812.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001812.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001813.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001813.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001814.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001814.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001815.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001815.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001816.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001816.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001817.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001817.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001818.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001818.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001819.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001819.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001820.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001820.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001821.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001821.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001822.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001822.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001823.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001823.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001824.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001824.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001825.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001825.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001826.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001826.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001827.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001827.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001828.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001828.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001829.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001829.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001830.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001830.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001831.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001831.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001832.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001832.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001833.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001833.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001834.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001834.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001835.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001835.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001836.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001836.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001837.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001837.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001838.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001838.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001839.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001839.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001840.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001840.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001841.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001841.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001842.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001842.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001843.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001843.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001844.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001844.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001845.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001845.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001846.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001846.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001847.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001847.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001848.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001848.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001849.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001849.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001850.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001850.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001851.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001851.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001852.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001852.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001853.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001853.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001854.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001854.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001855.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001855.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001856.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001856.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001857.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001857.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001858.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001858.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001859.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001859.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001860.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001860.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001861.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001861.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001862.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001862.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001863.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001863.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001864.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001864.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001865.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001865.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001866.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001866.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001867.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001867.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001868.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001868.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001869.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001869.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001870.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001870.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001871.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001871.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001872.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001872.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001873.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001873.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001874.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001874.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001875.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001875.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001876.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001876.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001877.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001877.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001878.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001878.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001879.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001879.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001880.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001880.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001881.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001881.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001882.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001882.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001883.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001883.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001884.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001884.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001885.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001885.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001886.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001886.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001887.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001887.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001888.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001888.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001889.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001889.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001890.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001890.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001891.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001891.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001892.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001892.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001893.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001893.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001894.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001894.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001895.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001895.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001896.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001896.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001897.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001897.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001898.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001898.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001899.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001899.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001900.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001900.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001901.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001901.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001902.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001902.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001903.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001903.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001904.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001904.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001905.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001905.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001906.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001906.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001907.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001907.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001908.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001908.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001909.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001909.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001910.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001910.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001911.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001911.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001912.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001912.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001913.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001913.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001914.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001914.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001915.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001915.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001916.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001916.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001917.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001917.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001918.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001918.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001919.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001919.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001920.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001920.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001921.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001921.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001922.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001922.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001923.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001923.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001924.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001924.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001925.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001925.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001926.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001926.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001927.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001927.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001928.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001928.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001929.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001929.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001930.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001930.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001931.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001931.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001932.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001932.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001933.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001933.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001934.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001934.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001935.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001935.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001936.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001936.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001937.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001937.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001938.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001938.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001939.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001939.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001940.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001940.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001941.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001941.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001942.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001942.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001943.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001943.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001944.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/001944.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/001945.png
# ...
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003307.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003308.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003308.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003309.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003309.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003310.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003310.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003311.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003311.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003312.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003312.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003313.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003313.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003314.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003314.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003315.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003315.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003316.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003316.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003317.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003317.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003318.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003318.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003319.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003319.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003320.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003320.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003321.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003321.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003322.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003322.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003323.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003323.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003324.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003324.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003325.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003325.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003326.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003326.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003327.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003327.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003328.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003328.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003329.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003329.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003330.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003330.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003331.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003331.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003332.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003332.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003333.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003333.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003334.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003334.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003335.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003335.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003336.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003336.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003337.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003337.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003338.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003338.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003339.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003339.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003340.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003340.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003341.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003341.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003342.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003342.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003343.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003343.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003344.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003344.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003345.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003345.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003346.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003346.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003347.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003347.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003348.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003348.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003349.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003349.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003350.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003350.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003351.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003351.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003352.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003352.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003353.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003353.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003354.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003354.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003355.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003355.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003356.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003356.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003357.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003357.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003358.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003358.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003359.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003359.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003360.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003360.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003361.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003361.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003362.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003362.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003363.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003363.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003364.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003364.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003365.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003365.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003366.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003366.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003367.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003367.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003368.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003368.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003369.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003369.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003370.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003370.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003371.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003371.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003372.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003372.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003373.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003373.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003374.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003374.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003375.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003375.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003376.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003376.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003377.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003377.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003378.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003378.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003379.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003379.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003380.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003380.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003381.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003381.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003382.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003382.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003383.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003383.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003384.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003384.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003385.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003385.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003386.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003386.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003387.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003387.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003388.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003388.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003389.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003389.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003390.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003390.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003391.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003391.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003392.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003392.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003393.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003393.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003394.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003394.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003395.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003395.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003396.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003396.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003397.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003397.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003398.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003398.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003399.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003399.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003400.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003400.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003401.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003401.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003402.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003402.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003403.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003403.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003404.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003404.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003405.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003405.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003406.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003406.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003407.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003407.png
# Processing: /Users/annethsivakumar/Downloads/Left_images2/003408.png
# Saved annotated image to: /Users/annethsivakumar/Downloads/classified_output/003408.png
# Processing complete.
